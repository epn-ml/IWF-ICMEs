# %%
import numpy as np
import pandas as pds
import pickle
import matplotlib.pyplot as plt
import resultgen as rs

#select spacecraft 0,1,2 and add/delete sep
sc = 'sep0'

# %%
starts, ends = rs.get_lags(4,sc)
cm, TN, FP, FN, TP = rs.get_cm(4,sc)
cme, FPe, FNe, TPe = rs.get_eventcm(4,sc)

# %%
from cm import make_confusion_matrix

labels = ['True Neg','False Pos','False Neg','True Pos']
categories = ['Background', 'ICME']
make_confusion_matrix(cm, 
                      group_names=labels,
                      categories=categories, 
                      cmap='binary')

# %%
recall, precision, dice, tss, iou = rs.metrics(TN,FP,FN,TP)
recalle, precisione, dicee, ioue = rs.eventmetrics(FPe,FNe,TPe)
# Out:
# POINTWISE RESULTS
# Recall:  0.5461342666242444
# Precision:  0.6181130716600648
# Dice Coefficient:  0.5798986486486486
# True Skill Statistics:  0.5293845753997874
# Intersection over Union:  0.40835018437016773
# EVENTWISE RESULTS
# Recall:  0.576271186440678
# Precision:  0.5024630541871922
# Dice Coefficient:  0.5368421052631579
# Intersection over Union:  0.3669064748201439
# False Positives:  101.0
# False Negatives:  75.0
# True Positives:  102.0

# %%
rs.lags(starts,ends)

# %%
print('Mean Absolute Error of Start Times: ', np.mean(np.abs(starts))/120)
print('Mean Absolute Error of End Times: ', np.mean(np.abs(ends))/120)
# Out:
# Mean Absolute Error of Start Times:  3.6732026143790852
# Mean Absolute Error of End Times:  4.21609477124183
